# %%
import os
foldername ='G:\Angela\EPM\downsampled_videos'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4':

        print(ii[:7])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 5
#       1 import os
#       2 foldername ='G:\Angela\EPM\downsampled_videos'
# ----> 5 for i, ii in enumerate(os.listdir(foldername)):
#       7     if ii[-4:] == '.mp4':
#       9         print(ii[:7])
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'G:\\Angela\\EPM\\downsampled_videos'

# %%
import os

#insert path name here

foldername = r'G:\Angela\TOR\downsampled_videos\test'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4':

        print(ii)
# Out:
# ELGH-02517_OF_20240122_154030437downsampled.mp4
# ELGH-02517_OF_SMALLER_20240122_154030437downsampled.mp4
# ELGH-02582_OF_20240122_183239689downsampled.mp4
# ELGH-02582_OF_SMALLER_20240122_183239689downsampled.mp4

# %%
import os
foldername =r'G:\Angela\Novel_arm_Y_maze\videos\test_only'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4':

        print(ii[28:36])
# Out:
# 20240122
# SMALLER_
# 20240122
# SMALLER_
