# %%
import os
foldername =r'G:\Angela\Loc_3h\ExplorationAnnotation'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.npy' and "shortened" in ii:

        print(ii)
# Out:
# 1118777_Loc_3h_TEST_20230918_133535862_shortened_annotations.npy
# 1118778_Loc_3h_TEST_20230918_134725711_shortened_annotations.npy
# 1118779_Loc_3h_TEST_20230918_135933703_shortened_annotations.npy
# 1118780_Loc_3h_TEST_20230918_141127306_shortened_annotations.npy
# 1118781_Loc_3h_TEST_20230918_142316462_shortened_annotations.npy
# 1118783_Loc_3h_TEST_20230918_145819098_shortened_annotations.npy
# 1118784_Loc_3h_TEST_20230918_150957313_shortened_annotations.npy
# 1118785_Loc_3h_TEST_20230918_152201934_shortened_annotations.npy
# 1118786_Loc_3h_TEST_20230918_153425254_shortened_annotations.npy
# 1118787_Loc_3h_TEST_20230918_154603819_shortened_annotations.npy
# 1118790_Loc_3h_TEST_20230918_143434889_shortened_annotations.npy
# 1118791_Loc_3h_TEST_20230918_144531726_shortened_annotations.npy
# 1118793_Loc_3h_TEST_20230918_155810861_shortened_annotations.npy
# 1118794_Loc_3h_TEST_20230918_160816967_shortened_annotations.npy
# 1118795_Loc_3h_TEST_20230918_161945962_shortened_annotations.npy
# 1118796_Loc_3h_TEST_20230918_163208654_shortened_annotations.npy
# 1118881_Loc_3h_TEST_20231004_130747963_shortened_annotations.npy
# 1118882_Loc_3h_TEST_20231004_132107473_shortened_annotations.npy
# 1118883_Loc_3h_TEST_20231004_133503570_shortened_annotations.npy
# 1119001_Loc_3h_TRAIN_20231023_103104730downsampled_shortened_annotations.npy
# 1119143_Loc_3h_TRAIN_20231113_105405418downsampled_shortened_annotations.npy
# 1119389_Loc_3h_TRAIN_20231130_103707109downsampled_shortened_annotations.npy
# 1120176_Loc_3h_TRAIN_20240325_113030068downsampled_shortened_annotations.npy

# %%
import os

#insert path name here

foldername = r'G:\Angela\TOR\downsampled_videos\test'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4':

        print(ii)
# Out:
# ELGH-02517_OF_20240122_154030437downsampled.mp4
# ELGH-02517_OF_SMALLER_20240122_154030437downsampled.mp4
# ELGH-02582_OF_20240122_183239689downsampled.mp4
# ELGH-02582_OF_SMALLER_20240122_183239689downsampled.mp4

# %%
import os
foldername =r'G:\Angela\Novel_arm_Y_maze\videos\test_only'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4':

        print(ii[28:36])
# Out:
# 20240122
# SMALLER_
# 20240122
# SMALLER_
