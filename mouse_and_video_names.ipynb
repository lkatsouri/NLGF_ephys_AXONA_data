# %%
import os
foldername =r'G:\Angela/NOR_15min\videos'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4' in ii:

        if 'TEST' in ii:
            print(ii[23:31])

        if 'TRAIN' in ii:
            print(ii[24:32])

# %%
import os

#insert path name here

foldername = r'G:\Angela\Sara\OF/videos'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4' in ii:

        print(ii[11:19])

# %%
import os
foldername =r'G:\Angela\Novel_arm_Y_maze\videos\test_only'


for i, ii in enumerate(os.listdir(foldername)):

    if ii[-4:] == '.mp4':

        print(ii[28:36])
