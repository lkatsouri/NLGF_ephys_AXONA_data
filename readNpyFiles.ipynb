# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\okeefelab\AppData\Local\Temp\ipykernel_16944\3269992828.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
"""To find the first insance of STart analysis and check if there is one"""
basepath = 'G:/Angela/Light-dark_box/downsampled_videos/'

import os
os.listdir(basepath)
directory = os.listdir(basepath)

annotpath = []
for i, ii in enumerate(directory):
    if ii[-3:] == 'npy':
        annotpath = np.append(annotpath, os.path.join(basepath, ii))  # this is to append the list with all the videos
        annotpath_list = annotpath.tolist()

for f, ff in enumerate(annotpath_list):
    annot = np.load(annotpath_list[f])
    startidx = np.where(annot == 'Start Analysis')[0][0]
    print(ff, startidx)
# Out:
# G:/Angela/Light-dark_box/downsampled_videos/1118777_LightDarkBox_20230922_125532654downsampled_annotation_set3.npy 130
# G:/Angela/Light-dark_box/downsampled_videos/1118778_LightDarkBox_20230922_131224482downsampled_annotation_set3.npy 101
# G:/Angela/Light-dark_box/downsampled_videos/1118779_LightDarkBox_20230922_132506666downsampled_annotation_set3.npy 109
# G:/Angela/Light-dark_box/downsampled_videos/1118780_LightDarkBox_20230922_135148511downsampled_annotation_set3.npy 111
# G:/Angela/Light-dark_box/downsampled_videos/1118781_LightDarkBox_20230922_133905089downsampled_annotation_set3.npy 128
# G:/Angela/Light-dark_box/downsampled_videos/1118783_LightDarkBox_20230922_145053622downsampled_annotation_set3.npy 117
# G:/Angela/Light-dark_box/downsampled_videos/1118784_LightDarkBox_20230922_150552834downsampled_annotation_set3.npy 121
# G:/Angela/Light-dark_box/downsampled_videos/1118785_LightDarkBox_20230922_151852024downsampled_annotation_set3.npy 124
# ...

# %%
test=np.load('/Users/loukia/Desktop/LocatioAnalysis/Loc_15/TrackingData/1119050_20231020_Loc_15_mousecoordx.npy')
print(test.shape)
print(type(test))
print(test)
# Out:
# (8, 18192)
# <class 'numpy.ndarray'>
# [[ 34.56  33.34  31.77 ... 504.2  504.2  504.2 ]
#  [ 37.9   37.53  37.53 ... 522.5  522.5  522.5 ]
#  [ 51.47  49.    47.6  ... 506.2  506.2  506.2 ]
#  ...
#  [ 86.8   79.06  74.8  ... 509.5  509.   508.  ]
#  [   nan 101.8  101.8  ... 541.5  537.5  530.5 ]
#  [   nan    nan    nan ... 467.   467.   467.  ]]

# %%
test2=np.load('F:Analysis_M1115859_20210415/kilosortData/templates.npy')
print(test2.shape)
print(type(test2))
print(test2)

# %%
test3 = np.load(r'G:\Angela\Y-maze\Results_OG\YMazeResults.npy', allow_pickle=True)

print(test3)
df = pd.DataFrame(test3)
df
# Out:
# [['MouseID' 'Date' 'Genotype' ... 'SameArmReturn_num'
#   'AlternateArmReturn_num' '%Alternation']
#  ['1119565' '20230720' 'wt' ... 6.0 11.0 52.77777777777778]
#  ['1119628' '20230720' 'NLGF' ... 5.0 15.0 52.5]
#  ...
#  ['1119788' '20240116' 'wt' ... 2.0 3.0 70.58823529411765]
#  ['1119789' '20240116' 'wt' ... 0.0 6.0 70.0]
#  ['1119794' '20240116' 'wt' ... 0.0 9.0 70.0]]
#            0         1         2       3       4               5  \
# 0    MouseID      Date  Genotype  Gender  Cohort  ArmEntries_num
# 1    1119565  20230720        wt       F  summer            38.0
# 2    1119628  20230720      NLGF       F  summer            42.0
# 3    1119630  20230720        wt       F  summer            54.0
# 4    1119631  20230720      NLGF       F  summer            40.0
# ..       ...       ...       ...     ...     ...             ...
# 99   1119741  20240116        wt       f       7            43.0
# 100  1119743  20240116        wt       f       7            35.0
# ...

# %%
test3 = np.load(r'G:\Angela\light-dark_box\TrackingData\1120807_20240624_light-dark_box_boxcoord.npy', allow_pickle=True)

print(test3)
df = pd.DataFrame(test3)
df
# Out:
# [[485. 171.]
#  [783. 168.]
#  [781. 775.]
#  [485. 779.]]
#        0      1
# 0  485.0  171.0
# 1  783.0  168.0
# 2  781.0  775.0
# 3  485.0  779.0

# %%
test4 = np.load('G:/Angela/Y-maze/TrackingData/1118777_20230914_Y-maze_mousecoordx.npy', allow_pickle=True)

# Convert the NumPy array to a pandas DataFrame
df = pd.DataFrame(test4)

# Display information about the DataFrame
print("DataFrame Shape:", df.shape)
print("DataFrame Info:")
print(df.info())

# Display the first few rows of the DataFrame
print("First Few Rows of DataFrame:")
print(df.head())
# Out:
# DataFrame Shape: (8, 14572)
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Columns: 14572 entries, 0 to 14571
# dtypes: float16(14572)
# memory usage: 227.8 KB
# None
# First Few Rows of DataFrame:
#     0       1       2       3       4       5       6       7       8      \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1  1006.0  1008.0  1008.5  1008.5  1008.5  1008.0  1008.0  1007.5  1007.5
# 2   995.5   996.0   996.5   996.0   996.0   994.5   994.0   994.0   994.0
# 3   980.5   980.5   980.5   980.5   980.5   980.0   979.5   979.5   979.5
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#     9      ...  14562  14563  14564  14565  14566  14567   14568  14569  \
# 0     NaN  ...  517.0  517.0  517.0  517.0  517.0  517.0  517.00  517.0
# 1  1007.5  ...  531.5  527.5  525.5  521.0  516.5  512.5  507.25  506.5
# ...
