# %%
import os.path
from tkinter import *

import cv2
import numpy as np
import imutils
import warnings
import colorsys
from tkinter import filedialog as fd

warnings.filterwarnings('ignore', category=DeprecationWarning)


def flick(x):
    pass


def basicControls(key, speed, i, framejump):
    if key == 'speedup':
        speed = speed - 5
        if speed < 1:
            speed = 1
        cv2.setTrackbarPos('Framerate', 'controls', speed)
        key = 'play'
    if key == 'slowdown':
        speed = speed + 5
        cv2.setTrackbarPos('Framerate', 'controls', speed)
        key = 'play'
    if key == 'rewind':
        i -= 1
        cv2.setTrackbarPos('Video', 'controls', i)
        key = 'pause'
    if key == 'fastforward':
        i += 1
        cv2.setTrackbarPos('Video', 'controls', i)
        key = 'pause'
    if key == 'ffastforward':
        i += framejump
        cv2.setTrackbarPos('Video', 'controls', i)
        key = 'pause'
    if key == 'rrewind':
        i -= framejump
        cv2.setTrackbarPos('Video', 'controls', i)
        key = 'pause'

    return key, speed, i


def behaviorLabels(listnumber):
    if listnumber == 1:
        labels = 'Conspecific #1 1: Headhead, 2: Anogenital, 3: GeneralSniff, 4: Approach, 5: Leaving, 6: Dominance, 7: Passive, 8: Following, 9: Allogrooming, 0: nan'
        behaviorkeys = {ord('1'): 'headhead', ord('2'): 'anogenital', ord('3'): 'sniff', ord('4'): 'approach',
                        ord('5'): 'leave', ord('6'): 'dominance', ord('7'): 'passive', ord('8'): 'follow', ord('9'): 'allogroom',
                        ord('0'): 'nan'}

    if listnumber == 2:
        labels = 'Conspecific #2 1: Headhead, 2: Anogenital, 3: GeneralSniff, 4: Approach, 5: Leaving, 6: Dominance, 7: Passive, 8: Following, 9: Allogrooming, 0: nan'
        behaviorkeys = {ord('1'): 'headhead', ord('2'): 'anogenital', ord('3'): 'sniff', ord('4'): 'approach',
                        ord('5'): 'leave', ord('6'): 'dominance', ord('7'): 'passive', ord('8'): 'follow',
                        ord('9'): 'allogroom',
                        ord('0'): 'nan'}
    if listnumber == 3:
        labels = '1: Start Analysis, 2: Stop Analysis, 3: Intervention'
        behaviorkeys = {ord('1'): 'Start Analysis', ord('2'): 'Stop Analysis', ord('3'): 'Intervention', ord('0'): 'nan'}
    if listnumber == 4:
        labels = 'Nonsocial 1: rearing, 2: self-grooming 2, 3: scratching, 0: nan'
        behaviorkeys = {ord('1'): 'rearing', ord('2'): 'groom', ord('3'): 'scratch', ord('0'): 'nan'}
    if listnumber == 5:
        labels = '1: object1, 2: object2, 3: object3, 4: object4, 0: nan'
        behaviorkeys = {ord('1'): 'object1', ord('2'): 'object2', ord('3'): 'object3', ord('4'): 'object4', ord('0'): 'nan'}
    if listnumber == 6:
        labels = '1: approach food, 2: sniff food, 3: eat food, 0: nan'
        behaviorkeys = {ord('1'): 'approach_food', ord('2'): 'sniff_food', ord('3'): 'eat_food', ord('0'): 'nan'}
    return labels, behaviorkeys


def addTracking(frame, xcoords, ycoords, probability, numbodyparts, i, reducefrac, threshold=.9):
    HSV_tuples = [(x / numbodyparts, 1, .75) for x in range(numbodyparts)]

    for x in range(numbodyparts):
        color = list(map(lambda j: int(j * 255), colorsys.hsv_to_rgb(*HSV_tuples[x])))

        if probability[i, x] > threshold:
            cv2.circle(frame, center=(int(xcoords[i, x] * reducefrac), int(ycoords[i, x] * reducefrac)), radius=4,
                       color=(color[2], color[1], color[0]), thickness=-1)
    return frame


def playVideo(widthset=500, framejump=10, annotation=False, listnumber=1, tracking=False, threshold=0.9):
    print('choose Video File')
    root = Tk()
    videopath = fd.askopenfilename()
    root.withdraw()
    videofolder = os.path.split(videopath)[0]
    videofile = os.path.split(videopath)[1]

    # create video windows
    cv2.namedWindow('image')
    cv2.namedWindow('controls')
    controls = np.zeros((50, 750), np.uint8)
    cv2.putText(controls, 'Z: play, X: pause, S: SlowDown, Q: SpeedUp, r: Rewind, t:rRewind, f: Fastforward, g: fFastforward, P: Exit',
                (40, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, 255)

    # import video
    cap = cv2.VideoCapture(videopath)
    framenum = int(cap.get(7))
    originalwidth = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
    reducefrac = widthset / originalwidth

    # initialize parameters for video viewing
    i = 0
    speed = 100
    cv2.createTrackbar('Video', 'controls', 0, int(framenum) - 1, flick)
    cv2.setTrackbarPos('Video', 'controls', 0)
    cv2.createTrackbar('Framerate', 'controls', 1, 200, flick)
    cv2.setTrackbarPos('Framerate', 'controls', speed)
    key = 'pause'
    initialkey = {ord('z'): 'play', ord('x'): 'pause', ord('s'): 'slowdown', ord('q'): 'speedup', ord('p'): 'quit',
                  ord('r'): 'rewind', ord('f'): 'fastforward', ord('g'): 'ffastforward', ord('t'): 'rrewind'}

    if annotation:
        cv2.namedWindow('labelbar')
        labelbar = np.zeros((50, 1500), np.uint8)
        cv2.putText(labelbar, behaviorLabels(listnumber)[0], (40, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, 255)
        cv2.imshow('labelbar', labelbar)
        setText = 'nan'
        initialkey.update(behaviorLabels(listnumber)[1])
        # try to load annotated file
        try:
            annotateValues = np.load(videofolder + '/' + videofile[:-4] + '_annotation_set'+str(listnumber)+'.npy')
            annotateValues = np.array(annotateValues, dtype='<U32')
        except:
            annotateValues = np.array(np.full(framenum, 'nan'), dtype='<U32')

    if tracking:
        root = Tk()
        trackingpath = fd.askopenfilename()
        root.withdraw()
        coords = np.loadtxt(trackingpath, delimiter=',', skiprows=3, dtype=np.float16)[:, 1:]
        numbodyparts = int(coords.shape[1] / 3)
        probcols = np.arange(2, coords.shape[1], 3)
        xcoords = coords[:, probcols - 2]
        ycoords = coords[:, probcols - 1]
        probability = coords[:, probcols]

    initialkey.update({-1: key, 27: 'exit'})

    shift_keycodes = {16}  # Add keycodes for Shift


    while i < framenum:
        cv2.imshow('controls', controls)
        try:
            if i == framenum - 1:
                i = 0

            # load individual frame
            cap.set(cv2.CAP_PROP_POS_FRAMES, i)
            (grabbed, frame) = cap.read(i)
            frame = imutils.resize(frame, width=widthset)
            cv2.putText(frame, str(i), (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255))
            if annotation:
                if annotateValues[i] != 'nan':
                    cv2.putText(frame, annotateValues[i], (300, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0))
                else:
                    annotateValues[i] = setText
                    cv2.putText(frame, annotateValues[i], (300, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255))
            if tracking:
                frame = addTracking(frame, xcoords, ycoords, probability, numbodyparts, i, reducefrac,
                                    threshold=threshold)
            cv2.imshow('image', frame)

            # key commands
            initialkey[-1] = key
            
            key = initialkey[cv2.waitKey(speed)]

            if key in shift_keycodes:
                continue  # Skip processing for Shift key
            
            if key == 'play':
                i += 1
                cv2.setTrackbarPos('Video', 'controls', i)
                continue
            elif key == 'pause':
                i = cv2.getTrackbarPos('Video', 'controls')
            elif key == 'quit':
                break
            elif (key == 'slowdown') | (key == 'speedup') | (key == 'rewind') | (key == 'fastforward') | (
                    key == 'ffastforward') | (key == 'rrewind'):
                key, speed, i = basicControls(key, speed, i, framejump)
            else:
                annotateValues[i] = key
                setText = key
                i = i
                key = 'pause'

        except KeyError:
            print('Error')

    cap.release()
    cv2.destroyAllWindows()
    if annotation:
        np.save(videofolder + '/' + videofile[:-4] + '_annotation_set'+str(listnumber)+'.npy', annotateValues)

# %%
playVideo(widthset=1200, framejump=20, annotation=True, listnumber=5, tracking=False)
# Out:
# choose Video File

# %% [raw]
# pwd

# %%
"""To find the first instance of Start analysis and check if there is one"""

basepath = 'G:/Angela/Y-maze/ManualAnnotation/'

import os
import numpy as np
os.listdir(basepath)
directory = os.listdir(basepath)


annotpath = []
for i, ii in enumerate(directory):
    if ii[-3:] == 'npy':
        annotpath = np.append(annotpath, os.path.join(basepath, ii)) # this is to append with all the videos
        annotpath_list = annotpath.tolist() # this is to make the numpy.ndarray into a list
print(len(annotpath_list))
      
for f, ff in enumerate(annotpath_list):
    annot = np.load(annotpath_list[f])
    startidx = np.where(annot == 'Start Analysis')[0][0]
    print(ff, startidx)
# Out:
# 103
# G:/Angela/Y-maze/ManualAnnotation/1118777_Ymaze_20230914_113837703downsampled_annotation_set3.npy 126
# G:/Angela/Y-maze/ManualAnnotation/1118778_Ymaze_20230914_103337614downsampled_annotation_set3.npy 149
# G:/Angela/Y-maze/ManualAnnotation/1118779_Ymaze_20230914_104422688downsampled_annotation_set3.npy 126
# G:/Angela/Y-maze/ManualAnnotation/1118780_Ymaze_20230914_110705745downsampled_annotation_set3.npy 142
# G:/Angela/Y-maze/ManualAnnotation/1118781_Ymaze__20230914_105704607downsampled_annotation_set3.npy 141
# G:/Angela/Y-maze/ManualAnnotation/1118783_Ymaze_20230913_153612499downsampled_annotation_set3.npy 170
# G:/Angela/Y-maze/ManualAnnotation/1118784_Ymaze_20230913_154639702downsampled_annotation_set3.npy 127
# G:/Angela/Y-maze/ManualAnnotation/1118785_Ymaze_20230913_155707769downsampled_annotation_set3.npy 114
# G:/Angela/Y-maze/ManualAnnotation/1118786_Ymaze_20230913_160919863downsampled_annotation_set3.npy 177
# G:/Angela/Y-maze/ManualAnnotation/1118787_Ymaze_20230913_162033669downsampled_annotation_set3.npy 127
# G:/Angela/Y-maze/ManualAnnotation/1118790_Ymaze_20230914_111806166downsampled_annotation_set3.npy 174
# G:/Angela/Y-maze/ManualAnnotation/1118791_Ymaze_20230914_112808948downsampled_annotation_set3.npy 216
# G:/Angela/Y-maze/ManualAnnotation/1118793_Ymaze_20230913_163100254downsampled_annotation_set3.npy 120
# G:/Angela/Y-maze/ManualAnnotation/1118794_Ymaze_20230913_164218356downsampled_annotation_set3.npy 144
# G:/Angela/Y-maze/ManualAnnotation/1118795_Ymaze_20230913_165228716downsampled_annotation_set3.npy 144
# G:/Angela/Y-maze/ManualAnnotation/1118796_Ymaze_20230913_170302270downsampled_annotation_set3.npy 149
# G:/Angela/Y-maze/ManualAnnotation/1118881_Ymaze_20231002_100751167downsampled_annotation_set3.npy 158
# G:/Angela/Y-maze/ManualAnnotation/1118882_Ymaze_20231002_101911705downsampled_annotation_set3.npy 169
# G:/Angela/Y-maze/ManualAnnotation/1118883_Ymaze_20231002_103319365downsampled_annotation_set3.npy 144
# G:/Angela/Y-maze/ManualAnnotation/1119001_Y_maze_20231018_110247276downsampled_annotation_set3.npy 198
# G:/Angela/Y-maze/ManualAnnotation/1119002_Y_maze_20231018_111311613downsampled_annotation_set3.npy 174
# G:/Angela/Y-maze/ManualAnnotation/1119036_Y_maze_20231018_112601533downsampled_annotation_set3.npy 238
# G:/Angela/Y-maze/ManualAnnotation/1119037_Y_maze_20231018_113756704downsampled_annotation_set3.npy 186
# G:/Angela/Y-maze/ManualAnnotation/1119038_Y_maze_20231018_120033188downsampled_annotation_set3.npy 172
# G:/Angela/Y-maze/ManualAnnotation/1119039_Y_maze_20231018_114923967downsampled_annotation_set3.npy 181
# G:/Angela/Y-maze/ManualAnnotation/1119040_Y_maze_20231018_130704696downsampled_annotation_set3.npy 215
# G:/Angela/Y-maze/ManualAnnotation/1119041_Y_maze_20231018_131835154downsampled_annotation_set3.npy 175
# G:/Angela/Y-maze/ManualAnnotation/1119042_Y_maze_20231018_133004856downsampled_annotation_set3.npy 186
# G:/Angela/Y-maze/ManualAnnotation/1119050_Y_maze_20231018_134141143downsampled_annotation_set3.npy 208
# G:/Angela/Y-maze/ManualAnnotation/1119060_Y_maze_20231018_135321988downsampled_annotation_set3.npy 198
# G:/Angela/Y-maze/ManualAnnotation/1119143_Y_maze_20231108_113606749downsampled_annotation_set3.npy 233
# G:/Angela/Y-maze/ManualAnnotation/1119144_Y_maze_20231108_114721606downsampled_annotation_set3.npy 219
# G:/Angela/Y-maze/ManualAnnotation/1119145_Y_maze_20231108_115906817downsampled_annotation_set3.npy 180
# G:/Angela/Y-maze/ManualAnnotation/1119146_Y_maze_20231108_121016492downsampled_annotation_set3.npy 251
# G:/Angela/Y-maze/ManualAnnotation/1119147_Y_maze_20231108_122214794downsampled_annotation_set3.npy 231
# G:/Angela/Y-maze/ManualAnnotation/1119148_Y_maze_20231108_123515417downsampled_annotation_set3.npy 164
# G:/Angela/Y-maze/ManualAnnotation/1119149_Y_maze_20231108_124810828downsampled_annotation_set3.npy 146
# G:/Angela/Y-maze/ManualAnnotation/1119155_Y_maze_20231108_110156297downsampled_annotation_set3.npy 243
# G:/Angela/Y-maze/ManualAnnotation/1119156_Y_maze_20231108_111253721downsampled_annotation_set3.npy 219
# G:/Angela/Y-maze/ManualAnnotation/1119157_Y_maze_20231108_112408251downsampled_annotation_set3.npy 190
# G:/Angela/Y-maze/ManualAnnotation/1119160_Y_maze_20231108_125828377downsampled_annotation_set3.npy 183
# G:/Angela/Y-maze/ManualAnnotation/1119181_Y-maze_20231128_114921163downsampled_annotation_set3.npy 198
# G:/Angela/Y-maze/ManualAnnotation/1119185_Y-maze_20231128_113851550downsampled_annotation_set3.npy 171
# G:/Angela/Y-maze/ManualAnnotation/1119389_Y-maze_20231128_105224491downsampled_annotation_set3.npy 214
# G:/Angela/Y-maze/ManualAnnotation/1119390_Y-maze_20231128_110551933downsampled_annotation_set3.npy 218
# G:/Angela/Y-maze/ManualAnnotation/1119391_Y-maze_20231128_111654372downsampled_annotation_set3.npy 195
# G:/Angela/Y-maze/ManualAnnotation/1119392_Y-maze_20231128_112735372downsampled_annotation_set3.npy 179
# G:/Angela/Y-maze/ManualAnnotation/1119464_Y-maze_20231208_104008718downsampled_annotation_set3.npy 202
# G:/Angela/Y-maze/ManualAnnotation/1119464_Ymaze_20230719_110654440downsampled_annotation_set3.npy 148
# G:/Angela/Y-maze/ManualAnnotation/1119507_Y-maze_20231208_105104131downsampled_annotation_set3.npy 271
# G:/Angela/Y-maze/ManualAnnotation/1119507_Ymaze_20230719_112904010downsampled_annotation_set3.npy 420
# G:/Angela/Y-maze/ManualAnnotation/1119508_Y-maze_20231208_110118427downsampled_annotation_set3.npy 214
# G:/Angela/Y-maze/ManualAnnotation/1119508_Ymaze_20230719_113946233downsampled_annotation_set3.npy 311
# G:/Angela/Y-maze/ManualAnnotation/1119510_Y-maze_20231208_111151002downsampled_annotation_set3.npy 228
# G:/Angela/Y-maze/ManualAnnotation/1119510_Ymaze_20230719_115027969downsampled_annotation_set3.npy 173
# G:/Angela/Y-maze/ManualAnnotation/1119511_Ymaze_20240110_173610989downsampled_annotation_set3.npy 236
# G:/Angela/Y-maze/ManualAnnotation/1119560_Ymaze_20230719_120133278downsampled_annotation_set3.npy 187
# G:/Angela/Y-maze/ManualAnnotation/1119560_Ymaze_20240110_155625658downsampled_annotation_set3.npy 212
# G:/Angela/Y-maze/ManualAnnotation/1119565_Ymaze_20230720_104204661downsampled_annotation_set3.npy 230
# G:/Angela/Y-maze/ManualAnnotation/1119565_Ymaze_20240110_165329419downsampled_annotation_set3.npy 231
# G:/Angela/Y-maze/ManualAnnotation/1119628_Ymaze_20230720_105332625downsampled_annotation_set3.npy 203
# G:/Angela/Y-maze/ManualAnnotation/1119628_Ymaze_20240110_170507078downsampled_annotation_set3.npy 145
# G:/Angela/Y-maze/ManualAnnotation/1119630_Ymaze_20230720_110428413downsampled_annotation_set3.npy 175
# G:/Angela/Y-maze/ManualAnnotation/1119630_Ymaze_20240110_171513235downsampled_annotation_set3.npy 401
# G:/Angela/Y-maze/ManualAnnotation/1119631_Ymaze_20230720_111524127downsampled_annotation_set3.npy 214
# G:/Angela/Y-maze/ManualAnnotation/1119631_Ymaze_20240110_172538566downsampled_annotation_set3.npy 325
# G:/Angela/Y-maze/ManualAnnotation/1119632_Ymaze_20230719_121234301downsampled_annotation_set3.npy 240
# G:/Angela/Y-maze/ManualAnnotation/1119632_Ymaze_20240110_160646688downsampled_annotation_set3.npy 321
# G:/Angela/Y-maze/ManualAnnotation/1119633_Ymaze_20230719_122330678downsampled_annotation_set3.npy 164
# G:/Angela/Y-maze/ManualAnnotation/1119633_Ymaze_20240110_161832853downsampled_annotation_set3.npy 283
# G:/Angela/Y-maze/ManualAnnotation/1119636_Ymaze_20230720_112809100downsampled_annotation_set3.npy 225
# G:/Angela/Y-maze/ManualAnnotation/1119636_Ymaze_20240110_174646861downsampled_annotation_set3.npy 184
# G:/Angela/Y-maze/ManualAnnotation/1119637_Ymaze_20230720_114508234downsampled_annotation_set3.npy 167
# G:/Angela/Y-maze/ManualAnnotation/1119637_Ymaze_20240110_175624716downsampled_annotation_set3.npy 364
# G:/Angela/Y-maze/ManualAnnotation/1119663_Ymaze_20230719_111810709downsampled_annotation_set3.npy 201
# G:/Angela/Y-maze/ManualAnnotation/1119663_Ymaze_20240110_162933294downsampled_annotation_set3.npy 368
# G:/Angela/Y-maze/ManualAnnotation/1119691_Y_maze_20240116_105241530downsampled_annotation_set3.npy 161
# G:/Angela/Y-maze/ManualAnnotation/1119723_Ymaze_20230720_115557416downsampled_annotation_set3.npy 205
# G:/Angela/Y-maze/ManualAnnotation/1119723_Y_maze_20240116_110358427downsampled_annotation_set3.npy 179
# G:/Angela/Y-maze/ManualAnnotation/1119724_Ymaze_20230720_120706980downsampled_annotation_set3.npy 192
# G:/Angela/Y-maze/ManualAnnotation/1119724_Y_maze_20240116_111510809downsampled_annotation_set3.npy 159
# G:/Angela/Y-maze/ManualAnnotation/1119737_Y_maze_20240116_114222254downsampled_annotation_set3.npy 212
# G:/Angela/Y-maze/ManualAnnotation/1119741_Y_maze_20240116_115426089downsampled_annotation_set3.npy 156
# G:/Angela/Y-maze/ManualAnnotation/1119743_Y_maze_20240116_120534668downsampled_annotation_set3.npy 144
# G:/Angela/Y-maze/ManualAnnotation/1119788_Y_maze_20240116_102829154downsampled_annotation_set3.npy 255
# G:/Angela/Y-maze/ManualAnnotation/1119789_Y_maze_20240116_103903365downsampled_annotation_set3.npy 195
# G:/Angela/Y-maze/ManualAnnotation/1119794_Y_maze_20240116_113053097downsampled_annotation_set3.npy 152
# G:/Angela/Y-maze/ManualAnnotation/1119959_Y-maze_20240220_122606850downsampled_annotation_set3.npy 171
# G:/Angela/Y-maze/ManualAnnotation/1119994_Y-maze_20240220_115150538downsampled_annotation_set3.npy 185
# G:/Angela/Y-maze/ManualAnnotation/1119996_Y-maze_20240220_114037159downsampled_annotation_set3.npy 187
# G:/Angela/Y-maze/ManualAnnotation/1120023_Y-maze_20240220_124834602downsampled_annotation_set3.npy 156
# G:/Angela/Y-maze/ManualAnnotation/1120027_Y-maze_20240220_123720213downsampled_annotation_set3.npy 132
# G:/Angela/Y-maze/ManualAnnotation/1120072_Y-maze_20240220_120306527downsampled_annotation_set3.npy 156
# G:/Angela/Y-maze/ManualAnnotation/1120073_Y-maze_20240220_121410222downsampled_annotation_set3.npy 178
# G:/Angela/Y-maze/ManualAnnotation/1120075_Y-maze_20240220_125926999downsampled_annotation_set3.npy 176
# G:/Angela/Y-maze/ManualAnnotation/1120151_Y-maze_20240320_110725718downsampled_annotation_set3.npy 177
# G:/Angela/Y-maze/ManualAnnotation/1120157_Y-maze_20240320_115144779downsampled_annotation_set3.npy 184
# G:/Angela/Y-maze/ManualAnnotation/1120158_Y-maze_20240320_120225391downsampled_annotation_set3.npy 166
# G:/Angela/Y-maze/ManualAnnotation/1120159_Y-maze_20240320_121317681downsampled_annotation_set3.npy 200
# G:/Angela/Y-maze/ManualAnnotation/1120163_Y-maze_20240320_122421011downsampled_annotation_set3.npy 242
# G:/Angela/Y-maze/ManualAnnotation/1120170_Y-maze_20240320_111820032downsampled_annotation_set3.npy 217
# G:/Angela/Y-maze/ManualAnnotation/1120175_Y-maze_20240320_112931211downsampled_annotation_set3.npy 187
# G:/Angela/Y-maze/ManualAnnotation/1120176_Y-maze_20240320_114019590downsampled_annotation_set3.npy 221

# %%
print("hi")

# %%
import numpy as np
test = np.load
