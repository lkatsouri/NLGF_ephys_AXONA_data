# %% [markdown]
# # Proteomic analysis of mouse run DRIX157

# %%
# read parquet file and print the content
import pandas as pd
df_report = pd.read_parquet('/Users/loukia/Library/CloudStorage/Dropbox-UCL/Loukia Katsouri/DataProtocolsEquipment/Protein work/Proteomics/2025-08-07_Dp1Tyb_3-4mo/Mouse/mouse/report.parquet')
print(df_report)
# Out:
#          Run.Index                   Run Channel           Precursor.Id  \
# 0                0   20250829_DRI_X157_1          AAAAAAAAAAAAAAAGAAGK2
# 1                1   20250829_DRI_X157_2          AAAAAAAAAAAAAAAGAAGK2
# 2                2   20250829_DRI_X157_3          AAAAAAAAAAAAAAAGAAGK2
# 3                3   20250829_DRI_X157_4          AAAAAAAAAAAAAAAGAAGK2
# 4                4   20250829_DRI_X157_5          AAAAAAAAAAAAAAAGAAGK2
# ...            ...                   ...     ...                    ...
# 6953102         57  20250829_DRI_X157_58             YYYWVINPADSSGIAPK3
# 6953103         62  20250829_DRI_X157_63             YYYWVINPADSSGIAPK3
# 6953104         63  20250829_DRI_X157_64             YYYWVINPADSSGIAPK3
# 6953105         66  20250829_DRI_X157_67             YYYWVINPADSSGIAPK3
# 6953106         67  20250829_DRI_X157_68             YYYWVINPADSSGIAPK3
#
#             Modified.Sequence     Stripped.Sequence  Precursor.Charge  \
# ...
