# %%
### Test ROI
# importing the module
import cv2
import os
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
import matplotlib.patches as mpatches
import numpy as np
import cv2
import imageio
import imutils

# function to display the coordinates of
# of the points clicked on the image 
def click_event(event, x, y, flags, params):
    global ix,iy
  
    # checking for left mouse clicks
    if event == cv2.EVENT_LBUTTONDOWN:
  
        # displaying the coordinates
        # on the Shell
        #print(x, ' ', y)
  
        # displaying the coordinates
        # on the image window
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(img, str(x) + ',' +
                    str(y), (x,y), font,
                    1, (255, 0, 0), 2)
        cv2.imshow('image', img)
        ix,iy = np.append(ix, x),np.append(iy,y)

# %%
#def pixelconversion(boxcoord, width, length):
#    xmin, xmax = np.min(boxcoord[:, 0]), np.max(boxcoord[:, 0])
#    ymin, ymax = np.min(boxcoord[:, 1]), np.max(boxcoord[:, 1])

#    wconversion = (xmax - xmin) / width
#    lconversion = (ymax - ymin) / length

#    conversion = np.mean((wconversion, lconversion))

#    return conversion

# %%
videopath = 'K:/BLA00/20230515_freelymoving/Video/BLA00_freelymoving_video_20230515_152345.avi'
width, length = 70,100
widthset=500

ix, iy = -1,-1
cap = cv2.VideoCapture(videopath)

(grabbed, img) = cap.read(1000)
img = imutils.resize(img, width=widthset)

cv2.imshow('image', img)
test = cv2.setMouseCallback('image', click_event)
cv2.waitKey(0)
cv2.destroyAllWindows()

#convert to correct size
#originalwidth = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
#reducefrac = widthset / originalwidth

#ixmod, iymod = ix/reducefrac, iy/reducefrac

#xvalues = ixmod[1:]
#yvalues = iymod[1:]

#boxcoord = np.vstack((xvalues, yvalues)).T

#conversion = pixelconversion(boxcoord, width, length)
print('xcoord: ' + str(ix[1:]), 'ycoord: ' + str(iy[1:]))
#print(conversion)
# Out:
# xcoord: [ 83 386 199] ycoord: [ 72 165 291]
